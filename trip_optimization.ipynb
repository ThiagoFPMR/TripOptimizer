# %%
import osmnx as ox
import random
import folium 
import jax.numpy as jnp
from abc import ABC, abstractmethod
ox.__version__

# %%
class SimulatedAnnealing(ABC):
    def __init__(self, initial_temp):
        self.initial_temp = initial_temp
        
    @abstractmethod
    def cost(self, X):
        raise NotImplementedError
        
    @abstractmethod
    def mutate(self, X):
        raise NotImplementedError
        
    def acceptance_probability(self, old_cost, new_cost, iteration):
        return jnp.exp(-(new_cost - old_cost)/self.schedule(iteration))
    
    def schedule(self, iteration, cooling_rate = 0.8):
        return self.initial_temp * self.cooling_rate ** iteration
    
    @abstractmethod
    def __call__(self):
        returnNotImplementedError

# %%
class TripOptimizer(SimulatedAnnealing):
    def __init__(self,  
                 loc_graph, 
                 destinations, 
                 initial_temp, 
                 cooling_rate = 0.8,
                 transporation_mode = 'drive'):
        self.initial_temp = initial_temp
        self.cooling_rate = cooling_rate

        self.loc_graph = loc_graph
        # self.loc_graph = ox.graph_from_place(location, network_type = transporation_mode)
        self.destinations = destinations

        X = [destination[0] for destination in destinations]
        Y = [destination[1] for destination in destinations]
        
        self.destination_nodes = ox.distance.nearest_nodes(self.loc_graph, Y, X)
        
    def cost(self, X):
        """
        The cost defined as the distance traveled in this particular path.

        Args:
            X: A list containing the destionation nodes to be visited, in order. 
        """
        prev_distances = dict()
        distance_traveled = 0
        for i in range(1, len(X)):
            if (X[i - 1], X[i]) in prev_distances.keys(): 
                distance_traveled += prev_distances[(X[i - 1], X[i])]
                continue
            prev_distances[(X[i - 1], X[i])] = 0
            path = next(ox.routing.k_shortest_paths(self.loc_graph, X[i - 1], X[i], 1))
            for j in range(1, len(path)):
                road = self.loc_graph.edges[(path[j - 1], path[j], 0)]
                if 'travel_time' in road.keys():
                    distance_traveled += road['travel_time']
                    prev_distances[(X[i - 1], X[i])] += road['travel_time']
                    
        return distance_traveled

    def mutate(self, X):
        """Mutates the problem solution."""
        new_solution = X.copy()
        lower_limit = random.randint(0, len(X) - 1)
        upper_limit = random.randint(0, len(X) - 1)
        new_solution[lower_limit:upper_limit] = new_solution[lower_limit:upper_limit][::-1]
        return new_solution
        
    def __call__(self, limit_iter=50):
        """Runs the method."""
        current_path = self.destination_nodes
        current_cost = self.cost(current_path)
    
        print(current_path)
        print(current_cost)
        for k in range(limit_iter):
            print("Iteration:", k)
            
            new_path = self.mutate(current_path)
            new_cost = self.cost(new_path)

            if new_cost < current_cost:
                current_path = new_path
                current_cost = new_cost
            else:
                prob = self.acceptance_probability(current_cost, new_cost, k)
                if random.uniform(0, 1) <= prob:
                    current_path = new_path
                    current_cost = new_cost
    
            print("Route:", current_path)
            print("Cost:", current_cost)

        return current_path

# %%
recife = ox.graph_from_place('Recife, Brazil', network_type='drive')

recife = ox.speed.add_edge_speeds(recife)
recife = ox.speed.add_edge_travel_times(recife)

# %%
X = [-8.086164, -8.063707, -8.067305, -8.123594, -8.108837, -8.071182]
Y = [-34.893904, -34.874522, -34.962828, -34.899516, -34.890279, -34.881360]

destinations = list(zip(X, Y))

# %%
recife_trip = TripOptimizer(recife, destinations, 1000)

# %%
best_path = recife_trip(limit_iter=100)
# Out:
# [1639770158, 661046206, 2563332550, 652791938, 324206112, 5729319652]
# 3112.1000000000013
# Iteration: 0
# [1639770158, 661046206, 2563332550, 652791938, 324206112, 5729319652]
# Iteration: 95
# [2563332550, 652791938, 324206112, 1639770158, 661046206, 5729319652]
# 2164.9
# Iteration: 96
# [2563332550, 652791938, 324206112, 1639770158, 661046206, 5729319652]
# 2164.9
# Iteration: 97
# [2563332550, 652791938, 324206112, 1639770158, 661046206, 5729319652]
# 2164.9
# Iteration: 98
# [2563332550, 652791938, 324206112, 1639770158, 661046206, 5729319652]
# 2164.9
# Iteration: 99
# [2563332550, 652791938, 324206112, 1639770158, 661046206, 5729319652]
# 2164.9

# %%
print(destinations)
print(recife_trip.destination_nodes)
best_path
# Out:
# [(-8.086164, -34.893904), (-8.063707, -34.874522), (-8.067305, -34.962828), (-8.123594, -34.899516), (-8.108837, -34.890279), (-8.071182, -34.88136)]
# [1639770158, 661046206, 2563332550, 652791938, 324206112, 5729319652]
# [2563332550, 652791938, 324206112, 1639770158, 661046206, 5729319652]

# %%
# optimal cost
optimal_path = [2563332550, 652791938, 324206112, 1639770158, 5729319652, 661046206]
recife_trip.cost(optimal_path)
# Out:
# 2123.7999999999997

# %%
def plot_trip(place, graph, trip, style=None):
    kept_nodes = set(trip)
    
    for i in range(1, len(trip)):
        path = next(ox.routing.k_shortest_paths(graph, trip[i - 1], trip[i], 1))
        kept_nodes.update(path)
    
    route_graph = graph.subgraph(kept_nodes)
    nodes, streets = ox.utils_graph.graph_to_gdfs(route_graph)
    destinations = nodes[nodes.index.isin(trip)]

    if style == None:
        style = {'color': '#1A19AC', 'weight':'3'}

    m = folium.Map(location=ox.geocode(place))
    folium.GeoJson(streets, style_function=lambda x: style).add_to(m)
    folium.GeoJson(destinations, style_function=lambda x: style).add_to(m)
    
    return m

# %%
plot_trip('Recife, Brazil', recife, best_path)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_674af637a124cfeabc474ef5cdfd9cd2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_674af637a124cfeabc474ef5cdfd9cd2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_674af637a124cfeabc474ef5cdfd9cd2 = L.map(
#                 &quot;map_674af637a124cfeabc474ef5cdfd9cd2&quot;,
#                 {
#                     center: [-8.0584933, -34.8848193],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_26e4ac788b5abea2ccc8738fbb8a96d6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_26e4ac788b5abea2ccc8738fbb8a96d6.addTo(map_674af637a124cfeabc474ef5cdfd9cd2);
#
#
#         function geo_json_51da2c876aa1eeca475bdfda6b3fec25_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#1A19AC&quot;, &quot;weight&quot;: &quot;3&quot;};
#             }
#         }
#
#         function geo_json_51da2c876aa1eeca475bdfda6b3fec25_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_51da2c876aa1eeca475bdfda6b3fec25 = L.geoJson(null, {
#                 onEachFeature: geo_json_51da2c876aa1eeca475bdfda6b3fec25_onEachFeature,
#
#                 style: geo_json_51da2c876aa1eeca475bdfda6b3fec25_styler,
#         });
#
#         function geo_json_51da2c876aa1eeca475bdfda6b3fec25_add (data) {
#             geo_json_51da2c876aa1eeca475bdfda6b3fec25
#                 .addData(data);
#         }
#             geo_json_51da2c876aa1eeca475bdfda6b3fec25_add({&quot;bbox&quot;: [-34.9581618, -8.1249041, -34.8734713, -8.0564986], &quot;features&quot;: [{&quot;bbox&quot;: [-34.8864667, -8.1004084, -34.8858765, -8.0990883], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-34.8864667, -8.1004084], [-34.8863462, -8.1001221], [-34.8860946, -8.0995799], [-34.8859108, -8.0991622], [-34.8858765, -8.0990883]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;(1677445121, 1677445138, 0)&quot;, &quot;properties&quot;: {&quot;bridge&quot;: null, &quot;highway&quot;: &quot;secondary&quot;, &quot;lanes&quot;: &quot;4&quot;, &quot;length&quot;: 160.541, &quot;maxspeed&quot;: null, &quot;name&quot;: &quot;Avenida Conselheiro Aguiar&quot;, &quot;oneway&quot;: true, &quot;osmid&quot;: 859471548, &quot;ref&quot;: null, &quot;reversed&quot;: false, &quot;speed_kph&quot;: 43.5, &quot;travel_time&quot;: 13.3, &quot;tunnel&quot;: null}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-34.8819876, -8.0718941, -34.8816642, -8.0714046], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-34.8819876, -8.0718941], [-34.8818349, -8.0716666], [-34.8817802, -8.0715885], [-34.8817406, -8.0715257], [-34.8816642, -8.0714046]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;(1419491329, 5729319652, 0)&quot;, &quot;properties&quot;: {&quot;bridge&quot;: null, &quot;highway&quot;: &quot;tertiary&quot;, &quot;lanes&quot;: &quot;2&quot;, &quot;length&quot;: 65.051, &quot;maxspeed&quot;: null, &quot;name&quot;: &quot;Pra\u00e7a das Cinco Pontas&quot;, &quot;oneway&quot;: true, &quot;osmid&quot;: 967389666, &quot;ref&quot;: null, &quot;reversed&quot;: false, &quot;speed_kph&quot;: 34.1, &quot;travel_time&quot;: 6.9, &quot;tunnel&quot;: null}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-34.8789101, -8.0719999, -34.8780495, -8.0717087], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-34.8780495, -8.0717087], [-34.8785079, -8.0718823], [-34.8785882, -8.0719112], [-34.8787118, -8.0719556], [-34.8789101, -8.0719999]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;(7242961411, 1417460159, 0)&quot;, &quot;properties&quot;: {&quot;bridge&quot;: null, &quot;highway&quot;: &quot;secondary&quot;, &quot;lanes&quot;: &quot;4&quot;, &quot;length&quot;: 100.294, &quot;maxspeed&quot;: null, &quot;name&quot;: &quot;Avenida Sul&quot;, &quot;oneway&quot;: true, &quot;osmid&quot;: 704221525, &quot;ref&quot;: &quot;PE-007;PE-008;PE-009&quot;, &quot;reversed&quot;: false, &quot;speed_kph&quot;: 43.5, &quot;travel_time&quot;: 8.3, &quot;tunnel&quot;: null}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-34.8890005, -8.0869543, -34.8888275, -8.086787], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-34.8888275, -8.0869543], [-34.8890005, -8.086787]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;(1562716681, 1562737174, 0)&quot;, &quot;properties&quot;: {&quot;bridge&quot;: null, &quot;highway&quot;: &quot;tertiary&quot;, &quot;lanes&quot;: &quot;4&quot;, &quot;length&quot;: 26.623, &quot;maxspeed&quot;: null, &quot;name&quot;: &quot;Avenida Rep\u00fablica \u00c1rabe Unida&quot;, &quot;oneway&quot;: true, &quot;osmid&quot;: 151153197, &quot;ref&quot;: null, &quot;reversed&quot;: false, &quot;speed_

# %%
plot_trip('Recife, Brazil', recife, optimal_path)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0e42f4359b6709b7ac2cbff45aa518df {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0e42f4359b6709b7ac2cbff45aa518df&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0e42f4359b6709b7ac2cbff45aa518df = L.map(
#                 &quot;map_0e42f4359b6709b7ac2cbff45aa518df&quot;,
#                 {
#                     center: [-8.0584933, -34.8848193],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_64ae03fd6a5dc957ca4c54062326dd61 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_64ae03fd6a5dc957ca4c54062326dd61.addTo(map_0e42f4359b6709b7ac2cbff45aa518df);
#
#
#         function geo_json_2596f2ba4a12b3de77e2612d40a5a97d_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#1A19AC&quot;, &quot;weight&quot;: &quot;3&quot;};
#             }
#         }
#
#         function geo_json_2596f2ba4a12b3de77e2612d40a5a97d_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_2596f2ba4a12b3de77e2612d40a5a97d = L.geoJson(null, {
#                 onEachFeature: geo_json_2596f2ba4a12b3de77e2612d40a5a97d_onEachFeature,
#
#                 style: geo_json_2596f2ba4a12b3de77e2612d40a5a97d_styler,
#         });
#
#         function geo_json_2596f2ba4a12b3de77e2612d40a5a97d_add (data) {
#             geo_json_2596f2ba4a12b3de77e2612d40a5a97d
#                 .addData(data);
#         }
#             geo_json_2596f2ba4a12b3de77e2612d40a5a97d_add({&quot;bbox&quot;: [-34.9581618, -8.1249041, -34.874436, -8.0564986], &quot;features&quot;: [{&quot;bbox&quot;: [-34.8864667, -8.1004084, -34.8858765, -8.0990883], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-34.8864667, -8.1004084], [-34.8863462, -8.1001221], [-34.8860946, -8.0995799], [-34.8859108, -8.0991622], [-34.8858765, -8.0990883]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;(1677445121, 1677445138, 0)&quot;, &quot;properties&quot;: {&quot;bridge&quot;: null, &quot;highway&quot;: &quot;secondary&quot;, &quot;lanes&quot;: &quot;4&quot;, &quot;length&quot;: 160.541, &quot;maxspeed&quot;: null, &quot;name&quot;: &quot;Avenida Conselheiro Aguiar&quot;, &quot;oneway&quot;: true, &quot;osmid&quot;: 859471548, &quot;ref&quot;: null, &quot;reversed&quot;: false, &quot;speed_kph&quot;: 43.5, &quot;travel_time&quot;: 13.3}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-34.8819876, -8.0724582, -34.8811311, -8.0718941], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-34.8819876, -8.0718941], [-34.8816909, -8.072101], [-34.8811311, -8.0724582]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;(1419491329, 3258913208, 0)&quot;, &quot;properties&quot;: {&quot;bridge&quot;: null, &quot;highway&quot;: &quot;tertiary&quot;, &quot;lanes&quot;: &quot;1&quot;, &quot;length&quot;: 113.273, &quot;maxspeed&quot;: null, &quot;name&quot;: &quot;Rua Frei Caneca&quot;, &quot;oneway&quot;: true, &quot;osmid&quot;: 703556854, &quot;ref&quot;: null, &quot;reversed&quot;: false, &quot;speed_kph&quot;: 34.1, &quot;travel_time&quot;: 12.0}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-34.8819876, -8.0718941, -34.8816642, -8.0714046], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-34.8819876, -8.0718941], [-34.8818349, -8.0716666], [-34.8817802, -8.0715885], [-34.8817406, -8.0715257], [-34.8816642, -8.0714046]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;(1419491329, 5729319652, 0)&quot;, &quot;properties&quot;: {&quot;bridge&quot;: null, &quot;highway&quot;: &quot;tertiary&quot;, &quot;lanes&quot;: &quot;2&quot;, &quot;length&quot;: 65.051, &quot;maxspeed&quot;: null, &quot;name&quot;: &quot;Pra\u00e7a das Cinco Pontas&quot;, &quot;oneway&quot;: true, &quot;osmid&quot;: 967389666, &quot;ref&quot;: null, &quot;reversed&quot;: false, &quot;speed_kph&quot;: 34.1, &quot;travel_time&quot;: 6.9}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-34.8929547, -8.0745154, -34.8924934, -8.0731643], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-34.8929547, -8.0731643], [-34.8924934, -8.0745154]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;(3764747269, 3714522235, 0)&quot;, &quot;properties&quot;: {&quot;bridge&quot;: null, &quot;highway&quot;: &quot;tertiary&quot;, &quot;lanes&quot;: &quot;1&quot;, &quot;length&quot;: 158.587, &quot;maxspeed&quot;: null, &quot;name&quot;: &quot;Rua Ana Bezerra&quot;, &quot;oneway&quot;: true, &quot;osmid&quot;: 434762467, &quot;ref&quot;: null, &quot;reversed&quot;: false, &quot;speed_kph&quot;: 34.1, &quot;travel_time&quot;: 16.7}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-34.8936718, -8.0756568, -34.8929547, -8.0730849], &quot;geometry&quot
